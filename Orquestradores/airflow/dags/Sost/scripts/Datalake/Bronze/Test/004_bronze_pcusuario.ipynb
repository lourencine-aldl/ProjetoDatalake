# %%
import os
import math
import logging
from dataclasses import dataclass
from datetime import datetime, timezone
from pathlib import Path
from typing import Optional, Sequence, Iterator
from contextlib import contextmanager

import psycopg
from psycopg.rows import dict_row
from dotenv import load_dotenv

# %%
# ✅ CARREGAMENTO DE BIBLIOTECAS OBRIGATÓRIAS
try:
    import pandas as pd
    import pyarrow as pa
    import pyarrow.parquet as pq
    import s3fs
    print("✅ Todas as bibliotecas obrigatórias carregadas com sucesso!")
except ImportError as e:
    raise ImportError(f"❌ Erro ao carregar bibliotecas: {e}")

# ✅ MUDANÇA DE DIRETÓRIO PARA CARREGAR .ENV CORRETO
os.chdir("/home/Projetos/Docker/Orquestradores/airflow/dags/Sost/scripts/Datalake/Bronze")
print(f"✅ Diretório atual: {os.getcwd()}")

# ✅ SETUP DE LOGGING
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# ===========================
# DATACLASSES PARA CONFIGURAÇÃO
# ===========================

@dataclass(frozen=True)
class PostgresConfig:
    """Configuração PostgreSQL"""
    host: str
    port: int
    database: str
    user: str
    password: str

@dataclass(frozen=True)
class MinioConfig:
    """Configuração MinIO"""
    endpoint: str
    bucket: str
    access_key: str
    secret_key: str

@dataclass(frozen=True)
class TableSpec:
    """Especificação de tabela"""
    schema: str
    name: str
    chunk_rows: int = 200_000

# ===========================
# CARREGAMENTO DE CONFIGURAÇÃO
# ===========================

def load_postgres_config() -> PostgresConfig:
    """Carrega configuração PostgreSQL do .env"""
    load_dotenv(".env")
    
    host = os.getenv("POSTGRES_DW_HOST", "").strip()
    port = int(os.getenv("POSTGRES_DW_PORT", "5432").strip()) if os.getenv("POSTGRES_DW_PORT") else 5432
    database = os.getenv("POSTGRES_DW_DB", "").strip()
    user = os.getenv("POSTGRES_DW_USER", "").strip()
    password = os.getenv("POSTGRES_DW_PASSWORD", "").strip()
    
    if not (host and database and user and password):
        raise ValueError(
            f"❌ Configuração PostgreSQL incompleta:\n"
            f"  HOST: {host if host else 'VAZIO'} | PORT: {port}\n"
            f"  DATABASE: {database if database else 'VAZIO'} | USER: {user if user else 'VAZIO'}"
        )
    
    return PostgresConfig(
        host=host,
        port=port,
        database=database,
        user=user,
        password=password
    )

def load_minio_config() -> MinioConfig:
    """Carrega configuração MinIO do .env"""
    load_dotenv(".env")
    
    endpoint = os.getenv("MINIO_ENDPOINT", "").strip()
    bucket = os.getenv("MINIO_BUCKET_SOST", "").strip()
    access_key = os.getenv("MINIO_ROOT_USER", "").strip()
    secret_key = os.getenv("MINIO_ROOT_PASSWORD", "").strip()
    
    if not (endpoint and bucket and access_key and secret_key):
        raise ValueError(
            f"❌ Configuração MinIO incompleta:\n"
            f"  ENDPOINT: {endpoint[:20]}... | BUCKET: {bucket}\n"
            f"  ACCESS_KEY: {access_key[:5]}... | SECRET_KEY: {secret_key[:5] if secret_key else 'VAZIO'}..."
        )
    
    return MinioConfig(
        endpoint=endpoint,
        bucket=bucket,
        access_key=access_key,
        secret_key=secret_key
    )

# ===========================
# CONEXÕES
# ===========================

def minio_fs(cfg: MinioConfig) -> s3fs.S3FileSystem:
    """Cria conexão S3FileSystem com MinIO"""
    return s3fs.S3FileSystem(
        key=cfg.access_key,
        secret=cfg.secret_key,
        client_kwargs={"endpoint_url": cfg.endpoint},
        config_kwargs={"signature_version": "s3v4"},
        use_ssl=False,
    )

def pg_conn_str(cfg: PostgresConfig) -> str:
    """Constrói string de conexão PostgreSQL"""
    from urllib.parse import quote
    safe_password = quote(cfg.password, safe='')
    return (
        f"postgresql://{cfg.user}:{safe_password}@{cfg.host}:{cfg.port}/{cfg.database}"
    )

@contextmanager
def pg_connection(cfg: PostgresConfig):
    """Context manager para conexão PostgreSQL"""
    conn = psycopg.connect(pg_conn_str(cfg), autocommit=False)
    try:
        yield conn
    finally:
        conn.close()

# ===========================
# FUNÇÕES DE UTILIDADE
# ===========================

def build_select_sql(table_spec: TableSpec) -> str:
    """Constrói SQL de seleção"""
    return f"SELECT * FROM {table_spec.schema}.{table_spec.name};"

def count_rows(conn, table_spec: TableSpec) -> int:
    """Conta linhas na tabela"""
    sql = f"SELECT COUNT(*) as cnt FROM {table_spec.schema}.{table_spec.name};"
    with conn.cursor() as cur:
        cur.execute(sql)
        return cur.fetchone()[0]

def write_parquet_to_minio(
    df: pd.DataFrame,
    fs: s3fs.S3FileSystem,
    bucket: str,
    schema: str,
    table: str,
    chunk_idx: int,
    ingestion_dt: datetime,
    filename: str = None
) -> str:
    """Escreve parquet direto no MinIO sem passar pelo disco local"""
    df["_ingestion_ts_utc"] = ingestion_dt.isoformat()
    df["_ingestion_date"] = ingestion_dt.date().isoformat()

    # ✅ Usa nome customizado ou gera com parte numerada
    if filename:
        file_part = filename
    else:
        file_part = f"part-{chunk_idx:05d}.parquet"
    
    s3_path = f"s3://{bucket}/bronze/004_bronze_pcusuario/{file_part}"

    table_pa = pa.Table.from_pandas(df, preserve_index=False)
    
    # ✅ Escreve direto no S3/MinIO (sem cache local)
    with fs.open(s3_path, "wb") as f:
        pq.write_table(table_pa, f, compression="snappy")
    
    logger.info(f"✅ Arquivo escrito: {s3_path}")
    return s3_path

# ===========================
# FUNÇÃO PRINCIPAL DE EXTRAÇÃO
# ===========================

def extract_to_minio(
    conn: psycopg.Connection,
    fs: s3fs.S3FileSystem,
    table_spec: TableSpec,
    minio_cfg: MinioConfig,
    ingestion_dt: datetime
) -> dict:
    """Extrai tabela PostgreSQL → MinIO usando cursor servidor-side"""
    
    logger.info(f"🚀 Iniciando extração: {table_spec.schema}.{table_spec.name}")
    
    # Conta linhas totais
    total_rows = count_rows(conn, table_spec)
    logger.info(f"📊 Total de linhas: {total_rows}")
    
    sql = build_select_sql(table_spec)
    stats = {
        "total_rows": total_rows,
        "chunks_created": 0,
        "files_written": 0,
        "bytes_written": 0
    }
    
    # ✅ CURSOR SERVIDOR-SIDE: Não carrega tudo em memória
    with conn.transaction():
        with conn.cursor(name="cur_extraction", row_factory=dict_row) as cur:
            cur.itersize = table_spec.chunk_rows  # 200k por fetch
            cur.execute(sql)
            
            chunk_idx = 0
            while True:
                # Fetch de 200k linhas por vez
                rows = cur.fetchmany(table_spec.chunk_rows)
                if not rows:
                    break
                
                chunk_idx += 1
                logger.info(f"📦 Processando chunk {chunk_idx} ({len(rows)} linhas)...")
                
                # Converte para DataFrame
                df = pd.DataFrame(rows)
                
                # Escreve direto para MinIO
                s3_path = write_parquet_to_minio(
                    df=df,
                    fs=fs,
                    bucket=minio_cfg.bucket,
                    schema=table_spec.schema,
                    table=table_spec.name,
                    chunk_idx=chunk_idx,
                    ingestion_dt=ingestion_dt
                )
                
                stats["chunks_created"] += 1
                stats["files_written"] += 1
    
    logger.info(f"✅ Extração completa!")
    logger.info(f"📈 Estatísticas: {stats}")
    return stats

# ===========================
# EXECUÇÃO PRINCIPAL
# ===========================

def main():
    """Orquestra a extração completa"""
    try:
        logger.info("="*60)
        logger.info("🎯 INICIANDO EXTRAÇÃO BRONZE: pcusuario")
        logger.info("="*60)
        
        # Carrega configurações
        pg_cfg = load_postgres_config()
        minio_cfg = load_minio_config()
        logger.info(f"✅ Configurações carregadas")
        logger.info(f"   PostgreSQL: {pg_cfg.host}:{pg_cfg.port}/{pg_cfg.database}")
        logger.info(f"   MinIO: {minio_cfg.endpoint} / {minio_cfg.bucket}")
        
        # Cria conexão MinIO
        fs = minio_fs(minio_cfg)
        logger.info(f"✅ Conexão MinIO estabelecida")
        
        # Define tabela a extrair
        table_spec = TableSpec(schema="public", name="pcusuari", chunk_rows=200_000)
        
        # Conecta ao PostgreSQL e extrai
        with pg_connection(pg_cfg) as conn:
            stats = extract_to_minio(
                conn=conn,
                fs=fs,
                table_spec=table_spec,
                minio_cfg=minio_cfg,
                ingestion_dt=datetime.now(timezone.utc)
            )
        
        logger.info("="*60)
        logger.info("✅ SUCESSO!")
        logger.info("="*60)
        return stats
        
    except Exception as e:
        logger.error(f"❌ ERRO: {e}", exc_info=True)
        raise

# ✅ EXECUTA EXTRAÇÃO
if __name__ == "__main__":
    result = main()
    print("\n" + "="*60)
    print("RESULTADO FINAL:")
    print("="*60)
    for key, value in result.items():
        print(f"{key}: {value}")
    print("="*60)
# Out:
# 2026-02-10 00:07:23,857 - INFO - ============================================================
# 2026-02-10 00:07:23,858 - INFO - 🎯 INICIANDO EXTRAÇÃO BRONZE: pcusuario
# 2026-02-10 00:07:23,859 - INFO - ============================================================
# 2026-02-10 00:07:23,862 - INFO - ✅ Configurações carregadas
# 2026-02-10 00:07:23,862 - INFO -    PostgreSQL: 209.50.228.232:5433/ERP
# 2026-02-10 00:07:23,862 - INFO -    MinIO: http://209.50.228.232:9000 / datalake-sost
# 2026-02-10 00:07:23,864 - INFO - ✅ Conexão MinIO estabelecida
# ✅ Todas as bibliotecas obrigatórias carregadas com sucesso!
# ✅ Diretório atual: /home/Projetos/Docker/Orquestradores/airflow/dags/Sost/scripts/Datalake/Bronze
# 2026-02-10 00:07:24,518 - INFO - 🚀 Iniciando extração: public.pcusuari
# 2026-02-10 00:07:24,780 - INFO - 📊 Total de linhas: 399
# 2026-02-10 00:07:25,830 - INFO - 📦 Processando chunk 1 (399 linhas)...
# 2026-02-10 00:07:26,739 - INFO - ✅ Arquivo escrito: s3://datalake-sost/bronze/004_bronze_pcusuario/part-00001.parquet
# 2026-02-10 00:07:27,129 - INFO - ✅ Extração completa!
# 2026-02-10 00:07:27,130 - INFO - 📈 Estatísticas: {'total_rows': 399, 'chunks_created': 1, 'files_written': 1, 'bytes_written': 0}
# 2026-02-10 00:07:27,131 - INFO - ============================================================
# 2026-02-10 00:07:27,131 - INFO - ✅ SUCESSO!
# 2026-02-10 00:07:27,131 - INFO - ============================================================
# ============================================================
# RESULTADO FINAL:
# ============================================================
# total_rows: 399
# chunks_created: 1
# files_written: 1
# bytes_written: 0
# ============================================================

# %%
# ===========================
# VALIDAÇÃO: LER ARQUIVO DO MINIO
# ===========================

def read_parquet_from_minio(
    fs: s3fs.S3FileSystem,
    s3_path: str,
    sample_rows: int = 5
) -> pd.DataFrame:
    """Lê arquivo parquet do MinIO e retorna amostra"""
    logger.info(f"📖 Lendo arquivo: {s3_path}")
    
    with fs.open(s3_path, "rb") as f:
        table = pq.read_table(f)
        df = table.to_pandas()
    
    logger.info(f"✅ Arquivo lido com sucesso!")
    logger.info(f"📊 Total de linhas: {len(df)}")
    logger.info(f"📋 Colunas: {', '.join(df.columns.tolist())}")
    
    return df

# ===========================
# TESTE: VALIDAR ARQUIVO NO MINIO
# ===========================

def validate_extraction():
    """Valida a extração lendo o arquivo do MinIO"""
    try:
        logger.info("="*60)
        logger.info("🔍 VALIDAÇÃO: Lendo parquet do MinIO")
        logger.info("="*60)
        
        # Carrega configurações
        minio_cfg = load_minio_config()
        fs = minio_fs(minio_cfg)
        
        # Caminho do arquivo em /bronze/004_bronze_pcusuario/
        s3_path = f"s3://{minio_cfg.bucket}/bronze/004_bronze_pcusuario/part-00001.parquet"
        
        # Lê arquivo
        df = read_parquet_from_minio(fs, s3_path)
        
        logger.info("\n📋 PREVIEW DOS DADOS:")
        logger.info(f"\n{df.head(10).to_string()}")
        
        logger.info(f"\n✅ VALIDAÇÃO COMPLETA!")
        
        return df
        
    except Exception as e:
        logger.error(f"❌ ERRO NA VALIDAÇÃO: {e}", exc_info=True)
        raise

# ✅ EXECUTA VALIDAÇÃO
if __name__ == "__main__":
    df_validation = validate_extraction()
    
    print("\n" + "="*60)
    print("RESUMO DA VALIDAÇÃO:")
    print("="*60)
    print(f"Linhas totais: {len(df_validation)}")
    print(f"Colunas: {len(df_validation.columns)}")
    print(f"Primeiras linhas:")
    print(df_validation.head())
    print("="*60)
# Out:
# 2026-02-08 01:56:49,570 - INFO - ============================================================
# 2026-02-08 01:56:49,572 - INFO - 🔍 VALIDAÇÃO: Lendo parquet do MinIO
# 2026-02-08 01:56:49,572 - INFO - ============================================================
# 2026-02-08 01:56:49,574 - INFO - 📖 Lendo arquivo: s3://datalake-sost/bronze/004_bronze_pcusuario.parquet
# 2026-02-08 01:56:50,514 - INFO - ✅ Arquivo lido com sucesso!
# 2026-02-08 01:56:50,515 - INFO - 📊 Total de linhas: 399
# 2026-02-08 01:56:50,516 - INFO - 📋 Colunas: codusur, nome, senha, tipovend, percent, percent2, endereco, cidade, estado, cep, telefone1, telefone2, cpf, ci, fax, bip, mens1, mens2, mens3, mens4, bloqueio, dtinicio, dttermino, motivo, dtnasc, firma, cgc, bairro, codsupervisor, conjuge, dtnasconjuge, tipofirma, numdep, dtultvenda, dtentregadoc, codcomocliente, ccorrente, email, dtinformatiza, numserieequip, proxnumped, ultnumped, numbanco, numagencia, numdvagencia, numccorrente, numdvccorrente, dtultalteracao, dtexclusao, vendedorqk, codequipe, permeta, codfilial, obs1, obs2, proxnumpedforca, bloqcomis, obsbloq, vlcorrente, vllimcred, numconselho, inss, vlvendaprev, coddistrib, dtlimentregadoc, maskpreposto, exportadados, numserieequip2, dtultpagconselho, inscmunicipal, praca1, praca2, endereco2, perdescmax, email2, bloqvendatlmk, areaatuacao, vlvendaminped, percmetadepto, tipocomissao, usadebcredrca, percacrescimovenda, numbancopoup, numccorrentepoup, numagenciapoup, numdvccorrentepoup, numdvagenciapoup, horainiconexaopalm, minutoiniconexaopalm, horafimconexaopalm, minutofimconexaopalm, proxcodclipalm, qtitenspedprev, qtpedprev, telprovedor, senhapop, usurpop, servsmtp, servpop, usurdialup, senhadialup, percacresfv, rotamasterfoods, numpedecf, usurlogin, senhalogin, usurdirfv, dirrecepcaoftp, direnvioftp, servftp, usurftp, senhaftp, permetametro, proxnumpedweb, codoperacao, tipopessoa, permiteadiantcomissao, indicecpfechcomissao, permaxvenda, indicerateiocomissao, usarrcaoperador, percommeta, numclipos, vlmaxtroca, comissaofixa, codmonitor, codpracaprincipal, usacobrancacartao, exportarecf, numccorrentealfa, validaracrescdescprecofixo, cpfaux, simplesnacional, diretorioassinatura, numnotabloco1, codcidade, codbairro, codcontacsrf, percinss, perccsrf, percpisnfservico, perccofinsnfservico, perciss, percirrf, codcontairrf, codcontaiss, codcontainss, codcontapis, codcontacofins, exportarparaforcavendas, modelopalm, obsforcavendas1, obsforcavendas2, obsforcavendas3, obsforcavendas4, visualizarproddeptosec, codcontab, codigocentrocusto, comissaoservicoprestado, fatorcomisliq, numdependentes, latitude, longitude, exportarcomissaofolharm, codrota, numseloinicial, numselofinal, numforminicial, numformfinal, utilizaselosefaz, serienf, usacontroleformselosefaz, proxnumform, proxnumselo, codcontasrf, numaidf, cpftitularcc, cpftitularcp, contribindividualinss, nit, partclubeitt, dtfimvigclubeitt, chapa_rm, valormetanatal, qtdmetanatal, calculardsr, ionsync, tipocontapagamento, permiteprodsemdistribuicao, codagentefunil, valorbonus, codagentecobranca, codgrupotelegram, codusurpg, dt_vmais, _ingestion_ts_utc, _ingestion_date
# 2026-02-08 01:56:50,516 - INFO -
# 📋 PREVIEW DOS DADOS:
# 2026-02-08 01:56:50,547 - INFO -
#    codusur                                nome senha tipovend percent percent2                                endereco           cidade estado       cep  telefone1   telefone2             cpf          ci  fax   bip mens1 mens2 mens3 mens4 bloqueio   dtinicio  dttermino  motivo     dtnasc firma  cgc         bairro  codsupervisor conjuge dtnasconjuge tipofirma numdep dtultvenda dtentregadoc codcomocliente ccorrente                      email dtinformatiza  numserieequip   proxnumped ultnumped numbanco numagencia numdvagencia numccorrente numdvccorrente      dtultalteracao dtexclusao vendedorqk  codequipe permeta codfilial  obs1  obs2  proxnumpedforca bloqcomis obsbloq vlcorrente vllimcred numconselho  inss vlvendaprev coddistrib dtlimentregadoc maskpreposto exportadados numserieequip2 dtultpagconselho inscmunicipal praca1 praca2 endereco2 perdescmax email2 bloqvendatlmk areaatuacao vlvendaminped percmetadepto tipocomissao usadebcredrca percacrescimovenda numbancopoup numccorrentepoup numagenciapoup numdvccorrentepoup numdvagenciapoup horainiconexaopalm minutoiniconexaopalm horafimconexaopalm minutofimconexaopalm  proxcodclipalm qtitenspedprev qtpedprev telprovedor senhapop usurpop servsmtp servpop usurdialup senhadialup percacresfv rotamasterfoods  numpedecf usurlogin senhalogin usurdirfv dirrecepcaoftp direnvioftp servftp usurftp senhaftp permetametro  proxnumpedweb codoperacao tipopessoa permiteadiantcomissao indicecpfechcomissao permaxvenda indicerateiocomissao usarrcaoperador percommeta numclipos vlmaxtroca comissaofixa  codmonitor codpracaprincipal usacobrancacartao exportarecf numccorrentealfa validaracrescdescprecofixo          cpfaux simplesnacional diretorioassinatura numnotabloco1  codcidade  codbairro codcontacsrf percinss perccsrf percpisnfservico perccofinsnfservico perciss percirrf codcontairrf codcontaiss codcontainss codcontapis codcontacofins exportarparaforcavendas modelopalm obsforcavendas1 obsforcavendas2 obsforcavendas3 obsforcavendas4 visualizarproddeptosec codcontab codigocentrocusto comissaoservicoprestado fatorcomisliq numdependentes latitude longitude exportarcomissaofolharm codrota numseloinicial numselofinal numforminicial numformfinal utilizaselosefaz serienf usacontroleformselosefaz proxnumform proxnumselo codcontasrf numaidf cpftitularcc cpftitularcp contribindividualinss   nit partclubeitt dtfimvigclubeitt chapa_rm valormetanatal qtdmetanatal calculardsr ionsync tipocontapagamento permiteprodsemdistribuicao  codagentefunil   valorbonus  codagentecobranca  codgrupotelegram codusurpg            dt_vmais                 _ingestion_ts_utc _ingestion_date
# 0        2       ALINE FERREIRA DE JESUS GOMES  None        I    None     3.00  R ALTO DA BELA VISTA Nº 211 - 2º ANDAR         SALVADOR     BA  41630360        NaN         NaN             NaN  0842292845  NaN  None  None  None  None  None        S 2008-09-17 2014-05-31     NaN        NaT  None  NaN         ITAPOA             17     NaN         None         I   None 2014-05-23          NaT           None      None     alinegomes@sost.com.br           NaT            2.0   2011447.00      None     None       None         None         None           None                 NaT       None       None        NaN    None         1  None  None          2011447         N    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             S               None         None             None           None               None             None               None                 None               None                 None           700.0           None      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None          F                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         NaN              None               NaN           N             None                          S             NaN               N                None          None        NaN        NaN         None     None     None             None                None    None     None         None        None         None        None           None                       S        NaN            None            None            None            None                      N      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None          NaN             None      NaN           None         None           S     NaN               None                        NaN            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 1        3              MARIA DA SILVA MILITÃO  None        I    None     0.14                     R MARIO KERTEZ Nº 6         SALVADOR     BA       NaN  3172-2400         NaN  923.886.985-53     5455509  NaN  None  None  None  None  None        N 2012-01-13 2016-03-02     NaN 1975-03-28  None  NaN  SAO CRISTOVAO             10     NaN         None         I   None 2016-02-26          NaT           None      None       mmilitao@sost.com.br           NaT            3.0   3032940.00      None     None       None         None         None           None 2025-08-26 10:03:57       None       None        NaN    None         1  None  None          3032868         N    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             S               None         None             None           None               None             None               None                 None               None                 None           700.0           0.00      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None          F                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         NaN              None               NaN           N             None                          S  00092388698553               N                None          None        NaN        NaN         None    11.00     None             None                None    None     None         None        None         None        None           None                       S        NaN            None            None            None            None                      S      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None            N             None      NaN           None         None           S     NaN               None                          N            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 2        4             ROSELI ALMEIDA DE BRITO  None        I    1.50     1.50                      CAMINHO 11 CASA 11         CAMAÇARI     BA  42800000  3172-2429         NaN  961.927.635-34  0802424058  NaN  None  None  None  None  None        N 2012-01-13        NaT  ferias 1980-02-12  None  NaN            NaN             17     NaN         None         I   None 2026-02-06          NaT           None      None         rbrito@sost.com.br           NaT            4.0   4099836.00      None     None       None         None         None           None 2025-03-03 16:05:25       None       None        NaN    0.00         1  None  None          4200485         N    None      -0.51    100.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None           C          None          None            E             S               None         None             None           None               None             None               None                 None               None                 None           700.0           0.00      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None          F                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         4.0              None               NaN           N             None                          S  00096192763534               N                None          None        NaN        NaN         None    11.00     None             None                None    None     None         None        None         None        None           None                       S        NaN            None            None            None            None                      S      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None            N             None      NaN   50000.000000   670.000000           S       Y               None                          N            1302  2611.320000              373.0       717656311.0      None 2026-02-06 23:36:04  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 3        5         THAYLA PORTELA MOTA MACHADO  None        I    None     3.00                                     NaN  LAURO DE FREITA     BA  42700000   31722436  7188701820             NaN  1289851352  NaN  None  None  None  None  None        S 2012-01-13 2014-03-31     NaN 1989-06-09  None  NaN   PITANGUEIRAS             17     NaN         None         I   None 2014-04-02          NaT           None      None  thaylaportela@sost.com.br           NaT            5.0   5015212.00      None     None       None         None         None           None                 NaT       None       None        NaN    None         1  None  None          5200000         N    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             S               None         None             None           None               None             None               None                 None               None                 None           700.0           None      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None          F                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         NaN              None               NaN           N             None                          S             NaN               N                None          None        NaN        NaN         None     None     None             None                None    None     None         None        None         None        None           None                       S        NaN            None            None            None            None                      S      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None          NaN             None      NaN           None         None           S     NaN               None                        NaN            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 4       11                          JANE REGIS  None        I    1.50     0.00                 R. BOA ESPERANÇA, Nº 3   LAURO DE FREITA     BA  42700000        NaN   3172-2431  781.040.925-53  0767126050  NaN  None  None  None  None  None        N 2009-11-01        NaT     NaN 1977-11-17  None  NaN         PORTÃO             17     NaN         None         I   None 2026-02-05          NaT           None      None         jregis@sost.com.br           NaT           11.0  11014366.00      None     None       None         None         None           None 2022-03-09 09:13:12       None       None       17.0    0.00         1  None  None         11200000         N    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            E             N               None         None             None           None               None             None               None                 None               None                 None           700.0           0.00      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None          F                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         4.0              None               NaN           N             None                          S  00078104092553               N                None          None        NaN        NaN         None     0.00     None             None                None    None     None         None        None         None        None           None                       S        NaN            None            None            None            None                      S      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None            N             None      NaN           None         None           S       Y               None                          N            1302     0.000000              373.0               0.0      None 2026-02-06 16:55:06  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 5       31                          RODRIGO B2  None        E    None     3.00                                     NaN              NaN    NaN       NaN        NaN         NaN             NaN         NaN  NaN  None  None  None  None  None        S 2012-03-28 2014-05-31     NaN        NaT  None  NaN            NaN             10     NaN         None         I   None 2012-04-01          NaT           None      None                        NaN           NaT           31.0  31000005.00      None     None       None         None         None           None                 NaT       None       None        NaN    None         1  None  None         31200000         S    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             S               None         None             None           None               None             None               None                 None               None                 None           700.0           0.00      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None        NaN                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         NaN              None               NaN           N             None                          N             NaN               N                None          None        NaN        NaN         None     None     None             None                None    None     None         None        None         None        None           None                       N        NaN            None            None            None            None                      S      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None          NaN             None      NaN           None         None           S     NaN               None                        NaN            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 6       34               SILVANA BASTOS SANTOS  None        I    None     3.00                                     NaN              NaN    NaN       NaN        NaN         NaN             NaN         NaN  NaN  None  None  None  None  None        S 2012-03-28 2014-05-31     NaN        NaT  None  NaN            NaN             10     NaN         None         I   None 2013-01-09          NaT           None      None                        NaN           NaT            NaN  34000112.00      None     None       None         None         None           None                 NaT       None       None        NaN    None         1  None  None         34200000         N    None       0.00      0.00        None   NaN        None       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             S               None         None             None           None               None             None               None                 None               None                 None           700.0           None      None        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None        NaN                     N                  NaN        None                 None               N     0.0000      None       None         0.00         NaN              None               NaN           N             None                          S             NaN               N                None          None        NaN        NaN         None     None     None             None                None    None     None         None        None         None        None           None                       S        NaN            None            None            None            None                      N      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None          NaN             None      NaN           None         None           S     NaN               None                        NaN            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 7       45                 FABRICIO RODY COSTA  None        E    None     3.00                                     NaN              NaN    NaN       NaN        NaN         NaN             NaN         NaN  NaN  None  None  None  None  None        S 2012-03-28 2014-05-31     NaN        NaT  None  NaN            NaN             10     NaN         None         I   None 2014-02-21          NaT           None      None                        NaN           NaT            NaN  45000400.00      None     None       None         None         None           None                 NaT       None       None        NaN    None         1  None  None         45200047         N    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             N               None         None             None           None               None             None               None                 None               None                 None           700.0           0.00      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None        NaN                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         NaN              None               NaN           N             None                          N             NaN               N                None          None        NaN        NaN         None     None     None             None                None    None     None         None        None         None        None           None                       N        NaN            None            None            None            None                      N      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None          NaN             None      NaN           None         None           S     NaN               None                        NaN            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 8       46       MARCUS VINICIUS DE MELO CHAVE  None        E    None     3.00                                     NaN              NaN    NaN       NaN        NaN         NaN             NaN         NaN  NaN  None  None  None  None  None        S 2012-03-28 2014-05-31     NaN        NaT  None  NaN            NaN             10     NaN         None         I   None 2013-10-15          NaT           None      None                        NaN           NaT            NaN  46000630.00      None     None       None         None         None           None                 NaT       None       None        NaN    None         1  None  None         46201149         N    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             S               None         None             None           None               None             None               None                 None               None                 None           700.0           0.00      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None        NaN                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         NaN              None               NaN           N             None                          N             NaN               N                None          None        NaN        NaN         None     None     None             None                None    None     None         None        None         None        None           None                       N        NaN            None            None            None            None                      N      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None          NaN             None      NaN           None         None           S     NaN               None                        NaN            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 9       52  ANTONIO CARLOS CORREIA DE OLIVEIRA  None        E    None     3.00                                     NaN              NaN    NaN       NaN        NaN         NaN             NaN         NaN  NaN  None  None  None  None  None        S 2014-05-31 2014-05-31     NaN 1963-01-13  None  NaN            NaN             10     NaN         None         I   None 2013-09-09          NaT           None      None                        NaN           NaT            NaN  52000068.00      None     None       None         None         None           None                 NaT       None       None        NaN    None         1  None  None         52200000         N    None       0.00      0.00        None   NaN        0.00       DIST             NaT         None         None            NaN             None           NaN   None   None       NaN       None   None          None         NaN          None          None            L             S               None         None             None           None               None             None               None                 None               None                 None           700.0           0.00      0.00        None     None    None     None    None       None        None        None             NaN        NaN      None       None      None           None        None    None    None     None         None              1        None          J                     N                  NaN        None                 None               N     0.0000      0E-8       None         0.00         NaN              None               NaN           N             None                          N             NaN               N                None          None        NaN        NaN         None     None     None             None                None    None     None         None        None         None        None           None                       N        NaN            None            None            None            None                      S      None              None                    None      1.000000           None      NaN       NaN                     NaN    None           None         None           None         None             None    None                      NaN        None        None        None    None         None         None                   NaN  None          NaN             None      NaN           None         None           S     NaN               None                        NaN            1302     0.000000                NaN               NaN      None 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 2026-02-08 01:56:50,548 - INFO -
# ✅ VALIDAÇÃO COMPLETA!
# ============================================================
# RESUMO DA VALIDAÇÃO:
# ============================================================
# Linhas totais: 399
# Colunas: 197
# Primeiras linhas:
#    codusur                           nome senha tipovend percent percent2  \
# 0        2  ALINE FERREIRA DE JESUS GOMES  None        I    None     3.00
# 1        3         MARIA DA SILVA MILITÃO  None        I    None     0.14
# 2        4        ROSELI ALMEIDA DE BRITO  None        I    1.50     1.50
# 3        5    THAYLA PORTELA MOTA MACHADO  None        I    None     3.00
# 4       11                     JANE REGIS  None        I    1.50     0.00
#
#                                  endereco           cidade estado       cep  \
# 0  R ALTO DA BELA VISTA Nº 211 - 2º ANDAR         SALVADOR     BA  41630360
# 1                     R MARIO KERTEZ Nº 6         SALVADOR     BA       NaN
# 2                      CAMINHO 11 CASA 11         CAMAÇARI     BA  42800000
# 3                                     NaN  LAURO DE FREITA     BA  42700000
# 4                 R. BOA ESPERANÇA, Nº 3   LAURO DE FREITA     BA  42700000
#
#    ... tipocontapagamento permiteprodsemdistribuicao codagentefunil  \
# 0  ...               None                        NaN           1302
# 1  ...               None                          N           1302
# 2  ...               None                          N           1302
# 3  ...               None                        NaN           1302
# 4  ...               None                          N           1302
#
#     valorbonus codagentecobranca codgrupotelegram codusurpg  \
# 0     0.000000               NaN              NaN      None
# 1     0.000000               NaN              NaN      None
# 2  2611.320000             373.0      717656311.0      None
# 3     0.000000               NaN              NaN      None
# 4     0.000000             373.0              0.0      None
#
#              dt_vmais                 _ingestion_ts_utc _ingestion_date
# 0 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 1 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 2 2026-02-06 23:36:04  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 3 2026-02-01 22:00:01  2026-02-08T01:56:38.033318+00:00      2026-02-08
# 4 2026-02-06 16:55:06  2026-02-08T01:56:38.033318+00:00      2026-02-08
#
# [5 rows x 197 columns]
# ============================================================

# %%
import os
import math
import logging
from dataclasses import dataclass
from datetime import datetime, timezone
from pathlib import Path
from typing import Optional, Sequence, Iterator
from contextlib import contextmanager

import psycopg
from psycopg.rows import dict_row
from dotenv import load_dotenv

# %%
# ✅ CARREGAMENTO DE BIBLIOTECAS OBRIGATÓRIAS
try:
    import pandas as pd
    import pyarrow as pa
    import pyarrow.parquet as pq
    import s3fs
    print("✅ Todas as bibliotecas obrigatórias carregadas com sucesso!")
except ImportError as e:
    raise ImportError(f"❌ Erro ao carregar bibliotecas: {e}")

# ✅ MUDANÇA DE DIRETÓRIO PARA CARREGAR .ENV CORRETO
os.chdir("/home/Projetos/Docker/Orquestradores/airflow/dags/Sost/scripts/Datalake/Bronze")
print(f"✅ Diretório atual: {os.getcwd()}")

# ✅ SETUP DE LOGGING
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# ===========================
# DATACLASSES PARA CONFIGURAÇÃO
# ===========================

@dataclass(frozen=True)
class PostgresConfig:
    """Configuração PostgreSQL"""
    host: str
    port: int
    database: str
    user: str
    password: str

@dataclass(frozen=True)
class MinioConfig:
    """Configuração MinIO"""
    endpoint: str
    bucket: str
    access_key: str
    secret_key: str

@dataclass(frozen=True)
class TableSpec:
    """Especificação de tabela"""
    schema: str
    name: str
    chunk_rows: int = 200_000

# ===========================
# CARREGAMENTO DE CONFIGURAÇÃO
# ===========================

def load_postgres_config() -> PostgresConfig:
    """Carrega configuração PostgreSQL do .env"""
    load_dotenv(".env")
    
    host = os.getenv("POSTGRES_DW_HOST", "").strip()
    port = int(os.getenv("POSTGRES_DW_PORT", "5432").strip()) if os.getenv("POSTGRES_DW_PORT") else 5432
    database = os.getenv("POSTGRES_DW_DB", "").strip()
    user = os.getenv("POSTGRES_DW_USER", "").strip()
    password = os.getenv("POSTGRES_DW_PASSWORD", "").strip()
    
    if not (host and database and user and password):
        raise ValueError(
            f"❌ Configuração PostgreSQL incompleta:\n"
            f"  HOST: {host if host else 'VAZIO'} | PORT: {port}\n"
            f"  DATABASE: {database if database else 'VAZIO'} | USER: {user if user else 'VAZIO'}"
        )
    
    return PostgresConfig(
        host=host,
        port=port,
        database=database,
        user=user,
        password=password
    )

def load_minio_config() -> MinioConfig:
    """Carrega configuração MinIO do .env"""
    load_dotenv(".env")
    
    endpoint = os.getenv("MINIO_ENDPOINT", "").strip()
    bucket = os.getenv("MINIO_BUCKET_SOST", "").strip()
    access_key = os.getenv("MINIO_ROOT_USER", "").strip()
    secret_key = os.getenv("MINIO_ROOT_PASSWORD", "").strip()
    
    if not (endpoint and bucket and access_key and secret_key):
        raise ValueError(
            f"❌ Configuração MinIO incompleta:\n"
            f"  ENDPOINT: {endpoint[:20]}... | BUCKET: {bucket}\n"
            f"  ACCESS_KEY: {access_key[:5]}... | SECRET_KEY: {secret_key[:5] if secret_key else 'VAZIO'}..."
        )
    
    return MinioConfig(
        endpoint=endpoint,
        bucket=bucket,
        access_key=access_key,
        secret_key=secret_key
    )

# ===========================
# CONEXÕES
# ===========================

def minio_fs(cfg: MinioConfig) -> s3fs.S3FileSystem:
    """Cria conexão S3FileSystem com MinIO"""
    return s3fs.S3FileSystem(
        key=cfg.access_key,
        secret=cfg.secret_key,
        client_kwargs={"endpoint_url": cfg.endpoint},
        config_kwargs={"signature_version": "s3v4"},
        use_ssl=False,
    )

def pg_conn_str(cfg: PostgresConfig) -> str:
    """Constrói string de conexão PostgreSQL"""
    from urllib.parse import quote
    safe_password = quote(cfg.password, safe='')
    return (
        f"postgresql://{cfg.user}:{safe_password}@{cfg.host}:{cfg.port}/{cfg.database}"
    )

@contextmanager
def pg_connection(cfg: PostgresConfig):
    """Context manager para conexão PostgreSQL"""
    conn = psycopg.connect(pg_conn_str(cfg), autocommit=False)
    try:
        yield conn
    finally:
        conn.close()

# ===========================
# FUNÇÕES DE UTILIDADE
# ===========================

def build_select_sql(table_spec: TableSpec) -> str:
    """Constrói SQL de seleção"""
    return f"SELECT * FROM {table_spec.schema}.{table_spec.name};"

def count_rows(conn, table_spec: TableSpec) -> int:
    """Conta linhas na tabela"""
    sql = f"SELECT COUNT(*) as cnt FROM {table_spec.schema}.{table_spec.name};"
    with conn.cursor() as cur:
        cur.execute(sql)
        return cur.fetchone()[0]

def write_parquet_to_minio(
    df: pd.DataFrame,
    fs: s3fs.S3FileSystem,
    bucket: str,
    schema: str,
    table: str,
    chunk_idx: int,
    ingestion_dt: datetime,
    filename: str = None
) -> str:
    """Escreve parquet direto no MinIO sem passar pelo disco local"""
    df["_ingestion_ts_utc"] = ingestion_dt.isoformat()
    df["_ingestion_date"] = ingestion_dt.date().isoformat()

    # ✅ Usa nome customizado ou gera com parte numerada
    if filename:
        file_part = filename
    else:
        file_part = f"part-{chunk_idx:05d}.parquet"
    
    s3_path = f"s3://{bucket}/bronze/{file_part}"

    table_pa = pa.Table.from_pandas(df, preserve_index=False)
    
    # ✅ Escreve direto no S3/MinIO (sem cache local)
    with fs.open(s3_path, "wb") as f:
        pq.write_table(table_pa, f, compression="snappy")
    
    logger.info(f"✅ Arquivo escrito: {s3_path}")
    return s3_path

# ===========================
# FUNÇÃO PRINCIPAL DE EXTRAÇÃO
# ===========================

def extract_to_minio(
    conn: psycopg.Connection,
    fs: s3fs.S3FileSystem,
    table_spec: TableSpec,
    minio_cfg: MinioConfig,
    ingestion_dt: datetime
) -> dict:
    """Extrai tabela PostgreSQL → MinIO usando cursor servidor-side"""
    
    logger.info(f"🚀 Iniciando extração: {table_spec.schema}.{table_spec.name}")
    
    # Conta linhas totais
    total_rows = count_rows(conn, table_spec)
    logger.info(f"📊 Total de linhas: {total_rows}")
    
    sql = build_select_sql(table_spec)
    stats = {
        "total_rows": total_rows,
        "chunks_created": 0,
        "files_written": 0,
        "bytes_written": 0
    }
    
    # ✅ CURSOR SERVIDOR-SIDE: Não carrega tudo em memória
    with conn.transaction():
        with conn.cursor(name="cur_extraction", row_factory=dict_row) as cur:
            cur.itersize = table_spec.chunk_rows  # 200k por fetch
            cur.execute(sql)
            
            chunk_idx = 0
            while True:
                # Fetch de 200k linhas por vez
                rows = cur.fetchmany(table_spec.chunk_rows)
                if not rows:
                    break
                
                chunk_idx += 1
                logger.info(f"📦 Processando chunk {chunk_idx} ({len(rows)} linhas)...")
                
                # Converte para DataFrame
                df = pd.DataFrame(rows)
                
                # Escreve direto para MinIO
                s3_path = write_parquet_to_minio(
                    df=df,
                    fs=fs,
                    bucket=minio_cfg.bucket,
                    schema=table_spec.schema,
                    table=table_spec.name,
                    chunk_idx=chunk_idx,
                    ingestion_dt=ingestion_dt,
                    filename="003_bronze_pcsupervisor.parquet"
                )
                
                stats["chunks_created"] += 1
                stats["files_written"] += 1
    
    logger.info(f"✅ Extração completa!")
    logger.info(f"📈 Estatísticas: {stats}")
    return stats

# ===========================
# EXECUÇÃO PRINCIPAL
# ===========================

def main():
    """Orquestra a extração completa"""
    try:
        logger.info("="*60)
        logger.info("🎯 INICIANDO EXTRAÇÃO BRONZE: pcsuperv")
        logger.info("="*60)
        
        # Carrega configurações
        pg_cfg = load_postgres_config()
        minio_cfg = load_minio_config()
        logger.info(f"✅ Configurações carregadas")
        logger.info(f"   PostgreSQL: {pg_cfg.host}:{pg_cfg.port}/{pg_cfg.database}")
        logger.info(f"   MinIO: {minio_cfg.endpoint} / {minio_cfg.bucket}")
        
        # Cria conexão MinIO
        fs = minio_fs(minio_cfg)
        logger.info(f"✅ Conexão MinIO estabelecida")
        
        # Define tabela a extrair
        table_spec = TableSpec(schema="public", name="pcsuperv", chunk_rows=200_000)
        
        # Conecta ao PostgreSQL e extrai
        with pg_connection(pg_cfg) as conn:
            stats = extract_to_minio(
                conn=conn,
                fs=fs,
                table_spec=table_spec,
                minio_cfg=minio_cfg,
                ingestion_dt=datetime.now(timezone.utc)
            )
        
        logger.info("="*60)
        logger.info("✅ SUCESSO!")
        logger.info("="*60)
        return stats
        
    except Exception as e:
        logger.error(f"❌ ERRO: {e}", exc_info=True)
        raise

# ✅ EXECUTA EXTRAÇÃO
if __name__ == "__main__":
    result = main()
    print("\n" + "="*60)
    print("RESULTADO FINAL:")
    print("="*60)
    for key, value in result.items():
        print(f"{key}: {value}")
    print("="*60)
# Out:
# 2026-02-10 00:07:36,028 - INFO - ============================================================
# 2026-02-10 00:07:36,029 - INFO - 🎯 INICIANDO EXTRAÇÃO BRONZE: pcsuperv
# 2026-02-10 00:07:36,029 - INFO - ============================================================
# 2026-02-10 00:07:36,032 - INFO - ✅ Configurações carregadas
# 2026-02-10 00:07:36,033 - INFO -    PostgreSQL: 209.50.228.232:5433/ERP
# 2026-02-10 00:07:36,033 - INFO -    MinIO: http://209.50.228.232:9000 / datalake-sost
# 2026-02-10 00:07:36,034 - INFO - ✅ Conexão MinIO estabelecida
# ✅ Todas as bibliotecas obrigatórias carregadas com sucesso!
# ✅ Diretório atual: /home/Projetos/Docker/Orquestradores/airflow/dags/Sost/scripts/Datalake/Bronze
# 2026-02-10 00:07:36,688 - INFO - 🚀 Iniciando extração: public.pcsuperv
# 2026-02-10 00:07:36,947 - INFO - 📊 Total de linhas: 47
# 2026-02-10 00:07:37,462 - INFO - 📦 Processando chunk 1 (47 linhas)...
# 2026-02-10 00:07:37,861 - INFO - ✅ Arquivo escrito: s3://datalake-sost/bronze/003_bronze_pcsupervisor.parquet
# 2026-02-10 00:07:38,247 - INFO - ✅ Extração completa!
# 2026-02-10 00:07:38,247 - INFO - 📈 Estatísticas: {'total_rows': 47, 'chunks_created': 1, 'files_written': 1, 'bytes_written': 0}
# 2026-02-10 00:07:38,248 - INFO - ============================================================
# 2026-02-10 00:07:38,249 - INFO - ✅ SUCESSO!
# 2026-02-10 00:07:38,249 - INFO - ============================================================
# ============================================================
# RESULTADO FINAL:
# ============================================================
# total_rows: 47
# chunks_created: 1
# files_written: 1
# bytes_written: 0
# ============================================================

# %%
# ===========================
# VALIDAÇÃO: LER ARQUIVO DO MINIO
# ===========================

def read_parquet_from_minio(
    fs: s3fs.S3FileSystem,
    s3_path: str,
    sample_rows: int = 5
) -> pd.DataFrame:
    """Lê arquivo parquet do MinIO e retorna amostra"""
    logger.info(f"📖 Lendo arquivo: {s3_path}")
    
    with fs.open(s3_path, "rb") as f:
        table = pq.read_table(f)
        df = table.to_pandas()
    
    logger.info(f"✅ Arquivo lido com sucesso!")
    logger.info(f"📊 Total de linhas: {len(df)}")
    logger.info(f"📋 Colunas: {', '.join(df.columns.tolist())}")
    
    return df

# ===========================
# TESTE: VALIDAR ARQUIVO NO MINIO
# ===========================

def validate_extraction():
    """Valida a extração lendo o arquivo do MinIO"""
    try:
        logger.info("="*60)
        logger.info("🔍 VALIDAÇÃO: Lendo parquet do MinIO")
        logger.info("="*60)
        
        # Carrega configurações
        minio_cfg = load_minio_config()
        fs = minio_fs(minio_cfg)
        
        # Caminho do arquivo
        s3_path = f"s3://{minio_cfg.bucket}/bronze/003_bronze_pcsupervisor.parquet"
        
        # Lê arquivo
        df = read_parquet_from_minio(fs, s3_path)
        
        logger.info("\n📋 PREVIEW DOS DADOS:")
        logger.info(f"\n{df.head(10).to_string()}")
        
        logger.info(f"\n✅ VALIDAÇÃO COMPLETA!")
        
        return df
        
    except Exception as e:
        logger.error(f"❌ ERRO NA VALIDAÇÃO: {e}", exc_info=True)
        raise

# ✅ EXECUTA VALIDAÇÃO
if __name__ == "__main__":
    df_validation = validate_extraction()
    
    print("\n" + "="*60)
    print("RESUMO DA VALIDAÇÃO:")
    print("="*60)
    print(f"Linhas totais: {len(df_validation)}")
    print(f"Colunas: {len(df_validation.columns)}")
    print(f"Primeiras linhas:")
    print(df_validation.head())
    print("="*60)

# %%
import os
import math
import logging
from dataclasses import dataclass
from datetime import datetime, timezone
from pathlib import Path
from typing import Optional, Sequence, Iterator
from contextlib import contextmanager

import psycopg
from psycopg.rows import dict_row
from dotenv import load_dotenv

# %%
# ✅ CARREGAMENTO DE BIBLIOTECAS OBRIGATÓRIAS
try:
    import pandas as pd
    import pyarrow as pa
    import pyarrow.parquet as pq
    import s3fs
    print("✅ Todas as bibliotecas obrigatórias carregadas com sucesso!")
except ImportError as e:
    raise ImportError(f"❌ Erro ao carregar bibliotecas: {e}")

# ✅ MUDANÇA DE DIRETÓRIO PARA CARREGAR .ENV CORRETO
os.chdir("/home/Projetos/Docker/Orquestradores/airflow/dags/Sost/scripts/Datalake/Bronze")
print(f"✅ Diretório atual: {os.getcwd()}")

# ✅ SETUP DE LOGGING
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# ===========================
# DATACLASSES PARA CONFIGURAÇÃO
# ===========================

@dataclass(frozen=True)
class PostgresConfig:
    """Configuração PostgreSQL"""
    host: str
    port: int
    database: str
    user: str
    password: str

@dataclass(frozen=True)
class MinioConfig:
    """Configuração MinIO"""
    endpoint: str
    bucket: str
    access_key: str
    secret_key: str

@dataclass(frozen=True)
class TableSpec:
    """Especificação de tabela"""
    schema: str
    name: str
    chunk_rows: int = 200_000

# ===========================
# CARREGAMENTO DE CONFIGURAÇÃO
# ===========================

def load_postgres_config() -> PostgresConfig:
    """Carrega configuração PostgreSQL do .env"""
    load_dotenv(".env")
    
    host = os.getenv("POSTGRES_DW_HOST", "").strip()
    port = int(os.getenv("POSTGRES_DW_PORT", "5432").strip()) if os.getenv("POSTGRES_DW_PORT") else 5432
    database = os.getenv("POSTGRES_DW_DB", "").strip()
    user = os.getenv("POSTGRES_DW_USER", "").strip()
    password = os.getenv("POSTGRES_DW_PASSWORD", "").strip()
    
    if not (host and database and user and password):
        raise ValueError(
            f"❌ Configuração PostgreSQL incompleta:\n"
            f"  HOST: {host if host else 'VAZIO'} | PORT: {port}\n"
            f"  DATABASE: {database if database else 'VAZIO'} | USER: {user if user else 'VAZIO'}"
        )
    
    return PostgresConfig(
        host=host,
        port=port,
        database=database,
        user=user,
        password=password
    )

def load_minio_config() -> MinioConfig:
    """Carrega configuração MinIO do .env"""
    load_dotenv(".env")
    
    endpoint = os.getenv("MINIO_ENDPOINT", "").strip()
    bucket = os.getenv("MINIO_BUCKET_SOST", "").strip()
    access_key = os.getenv("MINIO_ROOT_USER", "").strip()
    secret_key = os.getenv("MINIO_ROOT_PASSWORD", "").strip()
    
    if not (endpoint and bucket and access_key and secret_key):
        raise ValueError(
            f"❌ Configuração MinIO incompleta:\n"
            f"  ENDPOINT: {endpoint[:20]}... | BUCKET: {bucket}\n"
            f"  ACCESS_KEY: {access_key[:5]}... | SECRET_KEY: {secret_key[:5] if secret_key else 'VAZIO'}..."
        )
    
    return MinioConfig(
        endpoint=endpoint,
        bucket=bucket,
        access_key=access_key,
        secret_key=secret_key
    )

# ===========================
# CONEXÕES
# ===========================

def minio_fs(cfg: MinioConfig) -> s3fs.S3FileSystem:
    """Cria conexão S3FileSystem com MinIO"""
    return s3fs.S3FileSystem(
        key=cfg.access_key,
        secret=cfg.secret_key,
        client_kwargs={"endpoint_url": cfg.endpoint},
        config_kwargs={"signature_version": "s3v4"},
        use_ssl=False,
    )

def pg_conn_str(cfg: PostgresConfig) -> str:
    """Constrói string de conexão PostgreSQL"""
    from urllib.parse import quote
    safe_password = quote(cfg.password, safe='')
    return (
        f"postgresql://{cfg.user}:{safe_password}@{cfg.host}:{cfg.port}/{cfg.database}"
    )

@contextmanager
def pg_connection(cfg: PostgresConfig):
    """Context manager para conexão PostgreSQL"""
    conn = psycopg.connect(pg_conn_str(cfg), autocommit=False)
    try:
        yield conn
    finally:
        conn.close()

# ===========================
# FUNÇÕES DE UTILIDADE
# ===========================

def build_select_sql(table_spec: TableSpec) -> str:
    """Constrói SQL de seleção"""
    return f"SELECT * FROM {table_spec.schema}.{table_spec.name};"

def count_rows(conn, table_spec: TableSpec) -> int:
    """Conta linhas na tabela"""
    sql = f"SELECT COUNT(*) as cnt FROM {table_spec.schema}.{table_spec.name};"
    with conn.cursor() as cur:
        cur.execute(sql)
        return cur.fetchone()[0]

def write_parquet_to_minio(
    df: pd.DataFrame,
    fs: s3fs.S3FileSystem,
    bucket: str,
    schema: str,
    table: str,
    chunk_idx: int,
    ingestion_dt: datetime,
    filename: str = None
) -> str:
    """Escreve parquet direto no MinIO sem passar pelo disco local"""
    df["_ingestion_ts_utc"] = ingestion_dt.isoformat()
    df["_ingestion_date"] = ingestion_dt.date().isoformat()

    # ✅ Usa nome customizado ou gera com parte numerada
    if filename:
        file_part = filename
    else:
        file_part = f"part-{chunk_idx:05d}.parquet"
    
    s3_path = f"s3://{bucket}/bronze/{file_part}"

    table_pa = pa.Table.from_pandas(df, preserve_index=False)
    
    # ✅ Escreve direto no S3/MinIO (sem cache local)
    with fs.open(s3_path, "wb") as f:
        pq.write_table(table_pa, f, compression="snappy")
    
    logger.info(f"✅ Arquivo escrito: {s3_path}")
    return s3_path

# ===========================
# FUNÇÃO PRINCIPAL DE EXTRAÇÃO
# ===========================

def extract_to_minio(
    conn: psycopg.Connection,
    fs: s3fs.S3FileSystem,
    table_spec: TableSpec,
    minio_cfg: MinioConfig,
    ingestion_dt: datetime
) -> dict:
    """Extrai tabela PostgreSQL → MinIO usando cursor servidor-side"""
    
    logger.info(f"🚀 Iniciando extração: {table_spec.schema}.{table_spec.name}")
    
    # Conta linhas totais
    total_rows = count_rows(conn, table_spec)
    logger.info(f"📊 Total de linhas: {total_rows}")
    
    sql = build_select_sql(table_spec)
    stats = {
        "total_rows": total_rows,
        "chunks_created": 0,
        "files_written": 0,
        "bytes_written": 0
    }
    
    # ✅ CURSOR SERVIDOR-SIDE: Não carrega tudo em memória
    with conn.transaction():
        with conn.cursor(name="cur_extraction", row_factory=dict_row) as cur:
            cur.itersize = table_spec.chunk_rows  # 200k por fetch
            cur.execute(sql)
            
            chunk_idx = 0
            while True:
                # Fetch de 200k linhas por vez
                rows = cur.fetchmany(table_spec.chunk_rows)
                if not rows:
                    break
                
                chunk_idx += 1
                logger.info(f"📦 Processando chunk {chunk_idx} ({len(rows)} linhas)...")
                
                # Converte para DataFrame
                df = pd.DataFrame(rows)
                
                # Escreve direto para MinIO
                s3_path = write_parquet_to_minio(
                    df=df,
                    fs=fs,
                    bucket=minio_cfg.bucket,
                    schema=table_spec.schema,
                    table=table_spec.name,
                    chunk_idx=chunk_idx,
                    ingestion_dt=ingestion_dt,
                    filename="003_bronze_pcsupervisor.parquet"
                )
                
                stats["chunks_created"] += 1
                stats["files_written"] += 1
                # stats["bytes_written"] += df.memory_usage(deep=True).sum()
    
    logger.info(f"✅ Extração completa!")
    logger.info(f"📈 Estatísticas: {stats}")
    return stats

# ===========================
# EXECUÇÃO PRINCIPAL
# ===========================

def main():
    """Orquestra a extração completa"""
    try:
        logger.info("="*60)
        logger.info("🎯 INICIANDO EXTRAÇÃO BRONZE: pcsuperv")
        logger.info("="*60)
        
        # Carrega configurações
        pg_cfg = load_postgres_config()
        minio_cfg = load_minio_config()
        logger.info(f"✅ Configurações carregadas")
        logger.info(f"   PostgreSQL: {pg_cfg.host}:{pg_cfg.port}/{pg_cfg.database}")
        logger.info(f"   MinIO: {minio_cfg.endpoint} / {minio_cfg.bucket}")
        
        # Cria conexão MinIO
        fs = minio_fs(minio_cfg)
        logger.info(f"✅ Conexão MinIO estabelecida")
        
        # Define tabela a extrair
        table_spec = TableSpec(schema="public", name="pcsuperv", chunk_rows=200_000)
        
        # Conecta ao PostgreSQL e extrai
        with pg_connection(pg_cfg) as conn:
            stats = extract_to_minio(
                conn=conn,
                fs=fs,
                table_spec=table_spec,
                minio_cfg=minio_cfg,
                ingestion_dt=datetime.now(timezone.utc)
            )
        
        logger.info("="*60)
        logger.info("✅ SUCESSO!")
        logger.info("="*60)
        return stats
        
    except Exception as e:
        logger.error(f"❌ ERRO: {e}", exc_info=True)
        raise

# ✅ EXECUTA EXTRAÇÃO
if __name__ == "__main__":
    result = main()
    print("\n" + "="*60)
    print("RESULTADO FINAL:")
    print("="*60)
    for key, value in result.items():
        print(f"{key}: {value}")
    print("="*60)

# %%
# ===========================
# VALIDAÇÃO: LER ARQUIVO DO MINIO
# ===========================

def read_parquet_from_minio(
    fs: s3fs.S3FileSystem,
    s3_path: str,
    sample_rows: int = 5
) -> pd.DataFrame:
    """Lê arquivo parquet do MinIO e retorna amostra"""
    logger.info(f"📖 Lendo arquivo: {s3_path}")
    
    with fs.open(s3_path, "rb") as f:
        table = pq.read_table(f)
        df = table.to_pandas()
    
    logger.info(f"✅ Arquivo lido com sucesso!")
    logger.info(f"📊 Total de linhas: {len(df)}")
    logger.info(f"📋 Colunas: {', '.join(df.columns.tolist())}")
    
    return df

# ===========================
# TESTE: VALIDAR ARQUIVO NO MINIO
# ===========================

def validate_extraction():
    """Valida a extração lendo o arquivo do MinIO"""
    try:
        logger.info("="*60)
        logger.info("🔍 VALIDAÇÃO: Lendo parquet do MinIO")
        logger.info("="*60)
        
        # Carrega configurações
        minio_cfg = load_minio_config()
        fs = minio_fs(minio_cfg)
        
        # Caminho do arquivo
        s3_path = f"s3://{minio_cfg.bucket}/bronze/003_bronze_pcsupervisor.parquet"
        
        # Lê arquivo
        df = read_parquet_from_minio(fs, s3_path)
        
        logger.info("\n📋 PREVIEW DOS DADOS:")
        logger.info(f"\n{df.head(10).to_string()}")
        
        logger.info(f"\n✅ VALIDAÇÃO COMPLETA!")
        
        return df
        
    except Exception as e:
        logger.error(f"❌ ERRO NA VALIDAÇÃO: {e}", exc_info=True)
        raise

# ✅ EXECUTA VALIDAÇÃO
if __name__ == "__main__":
    df_validation = validate_extraction()
    
    print("\n" + "="*60)
    print("RESUMO DA VALIDAÇÃO:")
    print("="*60)
    print(f"Linhas totais: {len(df_validation)}")
    print(f"Colunas: {len(df_validation.columns)}")
    print(f"Primeiras linhas:")
    print(df_validation.head())
    print("="*60)
